# %%
import xarray
import netCDF4
import logging
import matplotlib.pyplot as plt
import numpy as np
logging.basicConfig(encoding='utf-8')
					# stream=sys.stdout)
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %%
logger.info('Load ANT model domain')
nc = netCDF4.Dataset('../data/ANT_Mesh.nc')
# print(nc)
elements = nc['/mesh/elements'][:]
x = nc['/mesh/x'][:]
y = nc['/mesh/y'][:]
# Out:
# INFO:root:Load ANT model domain

# %%
nc = netCDF4.Dataset('../data/IMIBIE2/basinNumbers_8km.nc')
print(nc)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): x(761), y(761)
#     variables(dimensions): float64 x(x), float64 y(y), int64 basinNumber(y, x)
#     groups:

# %%
print("ANT semic results.")
result = netCDF4.Dataset('./ANT_SEMIC_ERA5_day.nc')
display(result)
# Out:
# ANT semic results.
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     dimensions(sizes): time(12), nx(24655)
#     variables(dimensions): float64 smb(time, nx), float64 melt(time, nx), float64 swsn(time, nx), float64 tsurf(time, nx), float64 x(nx), float64 y(nx), int64 time(time)
#     groups:

# %%
fig, ax = plt.subplots()
im = ax.tricontourf(x, y, np.mean(result['melt'],axis=0),
			   triangles=elements-1)
fig.colorbar(im)
ax.set_aspect('equal')
# Out:
# C:\Users\inwoo\AppData\Local\Temp\ipykernel_65420\2285393219.py:2: UserWarning: The following kwargs were not used by contour: 'triangles'
#   im = ax.tricontourf(x, y, np.mean(result['melt'],axis=0),
